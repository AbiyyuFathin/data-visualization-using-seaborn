# %% [markdown]
# # TUGAS HANDS-ON ABIYYU
#
# Memasang library dari numpy, pandas, dan seaborn. Matplotlib tidak digunakan jadi tidak dipasang

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Membaca data wine.csv dengan library pandas

# %%
wines = pd.read_csv('C:/Users/abiyy/Downloads/wine.csv', index_col = 0)

# %% [markdown]
# ### Mengetahui analisis statistik dari file wine.csv

# %%
wines.describe()
# Out:
#               points          price
# count  150930.000000  137235.000000
# mean       87.888418      33.131482
# std         3.222392      36.322536
# min        80.000000       4.000000
# 25%        86.000000      16.000000
# 50%        88.000000      24.000000
# 75%        90.000000      40.000000
# max       100.000000    2300.000000

# %% [markdown]
# ### Mengetahui keberadaan data NaN dari wine.csv

# %%
pd.isnull(wines)
# Out:
#         country  description  designation  points  price  province  region_1  \
# 0         False        False        False   False  False     False     False
# 1         False        False        False   False  False     False     False
# 2         False        False        False   False  False     False     False
# 3         False        False        False   False  False     False     False
# 4         False        False        False   False  False     False     False
# 5         False        False        False   False  False     False     False
# 6         False        False        False   False  False     False     False
# 7         False        False        False   False  False     False     False
# 8         False        False        False   False  False     False     False
# 9         False        False        False   False  False     False     False
# 10        False        False        False   False  False     False     False
# ...

# %% [markdown]
# ### Mengetahui jumlah data NaN dari sub region_1 wine.csv

# %%
pd.isnull(wines.region_1).sum()
# Out:
# 25060

# %% [markdown]
# ### Mengetahui keberadaan data NaN dari sub country wine.csv
#
# Data NaN tersebut berada di baris-baris yang tercantum.

# %%
wines[pd.isnull(wines.country)]
# Out:
#        country                                        description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %% [markdown]
# ### Mengetahui keberadaan data NaN dari sub region_1 wine.csv
#
# Data NaN tersebut berada di baris-baris yang tercantum.

# %%
wines[pd.isnull(wines.region_1)]
# Out:
#              country                                        description  \
# 25       New Zealand  Yields were down in 2015, but intensity is up,...
# 30          Bulgaria  This Bulgarian Mavrud presents the nose with s...
# 42                US  This is an aromatic brooder with aromas of sco...
# 64          Portugal  This is a super-ripe, still very young wine. I...
# 74          Portugal  It is the ripe dark Alicante Bouschet that dom...
# 81            Israel  Dark red violet in color, this wine has aromas...
# 91          Portugal  The local Baga grape, better known for produci...
# 94          Portugal  This family-owned estate has produced an immed...
# 110         Portugal  This state-owned estate of forests and vineyar...
# 114     South Africa  Muted aromas of tart gooseberry and lime peel ...
# 118           France  This softly fruity wine has the lightest of ta...
# 119         Portugal  This broad, fruity wine brings out ripe berry ...
# ...

# %% [markdown]
# ### Mengetahui keberadaan data NaN dari sub region_2 wine.csv
#
# Data NaN tersebut berada di baris-baris yang tercantum.

# %%
wines[pd.isnull(wines.region_2)]
# Out:
#             country                                        description  \
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 10            Italy  Elegance, complexity and structure come togeth...
# 13           France  This wine is in peak condition. The tannins an...
# 17            Spain  Nicely oaked blackberry, licorice, vanilla and...
# 18           France  Coming from a seven-acre vineyard named after ...
# 21            Spain  Alluring, complex and powerful aromas of grill...
# 22            Spain  Tarry blackberry and cheesy oak aromas are app...
# 25      New Zealand  Yields were down in 2015, but intensity is up,...
# ...

# %% [markdown]
# ### Mengetahui keberadaan data NaN dari sub points wine.csv
#
# Tidak terdapat data NaN pada points.

# %%
wines[pd.isnull(wines.points)]
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, variety, winery]
# Index: []

# %% [markdown]
# ### Menghapus data Nan dari sub country wine.csv
#
# Yang ditampilkan hanya yang bernilai atau bukan NaN.

# %%
wines.country.dropna()
# Out:
# 0                  US
# 1               Spain
# 2                  US
# 3                  US
# 4              France
# 5               Spain
# 6               Spain
# 7               Spain
# 8                  US
# 9                  US
# 10              Italy
# 11                 US
# 12                 US
# 13             France
# 14                 US
# 15                 US
# 16                 US
# 17              Spain
# 18             France
# 19                 US
# 20                 US
# 21              Spain
# 22              Spain
# 23                 US
# 24                 US
# 25        New Zealand
# 26                 US
# 27                 US
# 28                 US
# 29                 US
#              ...
# 150900          Chile
# 150901          Chile
# 150902          Chile
# 150903          Chile
# 150904          Chile
# 150905          Chile
# 150906         France
# 150907         France
# 150908         France
# 150909         France
# ...

# %% [markdown]
# ### Menggambar histogram points
#
# Saya menggunakan library pandas.

# %%
wines.points.plot.hist()

# %% [markdown]
# ### Menggambar histogram price
#
# Saya menggunakan library pandas.

# %%
wines.price.plot.hist()

# %% [markdown]
# ### Menggambar histogram country
#
# Saya menggunakan library pandas. Namun, saya tidak menggambar histogram karena hasilnya tidak bisa menampilkan nama negaranya. Jadi, saya menggunakan bar karena fungsinya sama saja.

# %%
pd.Series(wines.country).value_counts().sort_index().plot('bar')

# %% [markdown]
# ### Menggambar grafik scatterplot dari (points-price), (points-country), (price-country)
#
# Saya menggunakan library seaborn.

# %%
sns.scatterplot(wines.points, wines.price)

# %% [markdown]
# Saya menggunakan library seaborn.

# %%
sns.scatterplot(wines.points, wines.country)

# %% [markdown]
# Saya menggunakan library seaborn.

# %%
sns.scatterplot(wines.price, wines.country)

# %% [markdown]
# ### Menggambar grafik line dari (points-price), (points-country), (price-country)
#
# Saya menggunakan library seaborn.

# %%
sns.lineplot(wines.points, wines.price)

# %% [markdown]
# Saya menggunakan library seaborn.

# %%
sns.lineplot(Clean_country, wines.price)

# %% [markdown]
# Saya menggunakan library seaborn.

# %%
sns.lineplot(Clean_country, wines.points)
